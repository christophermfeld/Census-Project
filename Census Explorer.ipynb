# %%
# some good general info for the census: http://www.opengeocode.org/tutorials/USCensusAPI.php

# census code wrapper: https://github.com/sunlightlabs/census

# %%
import pandas as pd 
import numpy as np
#import seaborn as sns
#sns.set(style="whitegrid", color_codes=True)
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('ggplot')
from pandas import DataFrame
from census import Census # this needs to be installed via $ pip install census
from us import states # this needs to be installed via $ pip install us

# %%
ck = Census("642e9046916aeaedd65d2e855468e3d7b66328d0")

county_table_load = pd.read_table("http://www2.census.gov/geo/docs/reference/codes/files/national_county.txt", header=None, names=['State_Abrv','State#','County#','County','Blank'],sep=",")

df_county_table = county_table_load

# variables for us to define which census year to utilize
census_year = 2014

df_county_table.head()
# Out:
#   State_Abrv  State#  County#          County Blank
# 0         AL       1        1  Autauga County    H1
# 1         AL       1        3  Baldwin County    H1
# 2         AL       1        5  Barbour County    H1
# 3         AL       1        7     Bibb County    H1
# 4         AL       1        9   Blount County    H1

# %%
# load the variables table

variables_table_load = pd.read_json("http://api.census.gov/data/2014/acs5/variables.json", typ="frame",orient="columns")

df_variables_table = variables_table_load

# convert the table to a series to make it a viewable dataframe
df_variables_table = df_variables_table.variables.apply(pd.Series).reset_index()
df_variables_table.columns = ['variables','concept','label','predicateOnly','predicateType']

df_variables_table.head()
# Out:
#   variables                 concept  \
# 0    AIANHH  Selectable Geographies
# 1   AIHHTLI  Selectable Geographies
# 2      AITS  Selectable Geographies
# 3    AITSCE  Selectable Geographies
# 4      ANRC  Selectable Geographies
#
#                                                label predicateOnly  \
# 0                                   FIPS AIANHH code           NaN
# 1  American Indian Trust Land/Hawaiian Home Land ...           NaN
# 2          American Indian Tribal Subdivision (FIPS)           NaN
# 3        American Indian Tribal Subdivision (Census)           NaN
# 4          Alaska Native Regional Corporation (FIPS)           NaN
#
#   predicateType
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# use this to explore what's in the labels -- note it is case sensitive
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_colwidth', -1)
df_variables_table_explorer = df_variables_table.copy()
df_variables_table[df_variables_table['label'].str.contains("")]
# Out:
#           variables                                             concept  \
# 0      AIANHH        Selectable Geographies
# 1      AIHHTLI       Selectable Geographies
# 2      AITS          Selectable Geographies
# 3      AITSCE        Selectable Geographies
# 4      ANRC          Selectable Geographies
# 5      B00001_001E   B00001.  Unweighted Sample Count of the Population
# 6      B00001_001M   B00001.  Unweighted Sample Count of the Population
# 7      B00002_001E   B00002.  Unweighted Sample Housing Units
# 8      B00002_001M   B00002.  Unweighted Sample Housing Units
# 9      B01001A_001E  B01001A.  SEX BY AGE (WHITE ALONE)
# 10     B01001A_001M  B01001A.  SEX BY AGE (WHITE ALONE)
# 11     B01001A_002E  B01001A.  SEX BY AGE (WHITE ALONE)
# 12     B01001A_002M  B01001A.  SEX BY AGE (WHITE ALONE)
# 13     B01001A_003E  B01001A.  SEX BY AGE (WHITE ALONE)
# 14     B01001A_003M  B01001A.  SEX BY AGE (WHITE ALONE)
# ...             ...                                 ...
# 45208  SDSEC         Selectable Geographies
# 45209  SDUNI         Selectable Geographies
# 45210  SLDL          Selectable Geographies
# 45211  SLDU          Selectable Geographies
# 45212  ST            Selectable Geographies
# 45213  STUSAB        Selectable Geographies
# 45214  SUBMCD        Selectable Geographies
# 45215  SUMLEVEL      Selectable Geographies
# 45216  TRACT         Selectable Geographies
# 45217  UA            Selectable Geographies
# 45218  UR            Selectable Geographies
# 45219  US            Selectable Geographies
# 45220  ZCTA5         Selectable Geographies
# 45221  for           Census API Geography Specification
# 45222  in            Census API Geography Specification
#
#                                                          label predicateOnly  \
# 0      FIPS AIANHH code                                         NaN
# 1      American Indian Trust Land/Hawaiian Home Land Indicator  NaN
# 2      American Indian Tribal Subdivision (FIPS)                NaN
# 3      American Indian Tribal Subdivision (Census)              NaN
# 4      Alaska Native Regional Corporation (FIPS)                NaN
# 5      Total                                                    NaN
# 6      Margin Of Error For!!Total                               NaN
# 7      Total                                                    NaN
# 8      Margin Of Error For!!Total                               NaN
# 9      Total:                                                   NaN
# 10     Margin Of Error For!!Total:                              NaN
# 11     Male:                                                    NaN
# 12     Margin Of Error For!!Male:                               NaN
# 13     Male:!!Under 5 years                                     NaN
# 14     Margin Of Error For!!Male:!!Under 5 years                NaN
# ...                                          ...                ...
# 45208  School District (Secondary)                              NaN
# 45209  School District (Unified)                                NaN
# 45210  State Legislative District Lower                         NaN
# 45211  State Legislative District Upper                         NaN
# 45212  State (FIPS Code)                                        NaN
# 45213  State Postal Abbreviation                                NaN
# 45214  Subbarrio (Puerto Rico)                                  NaN
# 45215  Geographic Summary Level                                 NaN
# 45216  Census Tract                                             NaN
# 45217  FIPS Urban Area code                                     NaN
# 45218  Urban/Rural                                              NaN
# 45219  United States Identifier                                 NaN
# 45220  FIPS ZCTA5 code                                          NaN
# 45221  Census API FIPS 'for' clause                             True
# 45222  Census API FIPS 'in' clause                              True
#
#       predicateType
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      int
# 6      int
# 7      int
# 8      int
# 9      int
# 10     int
# 11     int
# 12     int
# 13     int
# 14     int
# ...    ...
# 45208  NaN
# 45209  NaN
# 45210  NaN
# 45211  NaN
# 45212  NaN
# 45213  int
# 45214  NaN
# 45215  NaN
# 45216  NaN
# 45217  NaN
# 45218  int
# 45219  NaN
# 45220  NaN
# 45221  fips-for
# 45222  fips-in
#
# [45223 rows x 5 columns]

# %%
# total population for California
# male by age
m_cali_byage = pd.DataFrame(ck.acs5.get(('NAME',
                                                'B01001_007E', # male 18 to 19
                                                'B01001_008E', # male 20 years
                                                'B01001_009E', # male 21 years
                                                'B01001_010E', # male 22 to 24 years
                                                'B01001_011E', # male 25 to 29 years
                                                'B01001_012E', # male 30 to 34 years
                                                'B01001_013E', # male 35 to 39 years
                                                'B01001_014E', # male 40 to 44 years
                                                'B01001_015E', # male 45 to 49 years
                                                'B01001_016E', # male 50 to 54 years
                                                'B01001_017E', # male 55 to 59 years
                                                'B01001_018E', # male 60 to 51 years
                                                'B01001_019E', # male 62 to 64 years
                                                'B01001_020E', # male 65 to 66 years
                                                'B01001_021E', # male 67 to 69 years
                                                'B01001_022E'), # male 70 to 74 years 
                                          geo={'for': 'county:*', 
                                               'in': 'state:{}'.format(states.CA.fips)}, year=census_year))

m_cali_byage.head()
# Out:
#   B01001_007E B01001_008E B01001_009E B01001_010E B01001_011E B01001_012E  \
# 0  20721       10529       11250       33339       59098       59768
# 1  27          15          9           17          31          23
# 2  453         167         163         653         902         1057
# 3  4116        2865        2126        8534        7269        6580
# 4  494         252         176         631         976         829
#
#   B01001_013E B01001_014E B01001_015E B01001_016E B01001_017E B01001_018E  \
# 0  56709       58547       55736       54962       48199       17788
# 1  26          85          11          50          61          16
# 2  988         1637        1711        1780        1730        695
# 3  5887        5826        6162        7022        7154        2973
# 4  1074        974         1564        1826        1982        821
#
#   B01001_019E B01001_020E B01001_021E B01001_022E  \
# 0  22942       13507       15558       18608
# 1  32          12          31          12
# 2  961         737         814         916
# 3  4182        2755        2597        3600
# 4  1257        757         1115        1352
#
#                            NAME county state
# 0  Alameda County, California    001    06
# 1  Alpine County, California     003    06
# 2  Amador County, California     005    06
# 3  Butte County, California      007    06
# 4  Calaveras County, California  009    06

# %%
# total population for California
# femmale by age
f_cali_byage = pd.DataFrame(ck.acs5.get(('NAME',
                                                'B01001_031E', # female 18 to 19
                                                'B01001_032E', # female 20 years
                                                'B01001_033E', # female 21 years
                                                'B01001_034E', # female 22 to 24 years
                                                'B01001_035E', # female 25 to 29 years
                                                'B01001_036E', # female 30 to 34 years
                                                'B01001_037E', # female 35 to 39 years
                                                'B01001_038E', # female 40 to 44 years
                                                'B01001_039E', # female 45 to 49 years
                                                'B01001_040E', # female 50 to 54 years
                                                'B01001_041E', # female 55 to 59 years
                                                'B01001_042E', # female 60 to 51 years
                                                'B01001_043E', # female 62 to 64 years
                                                'B01001_044E', # female 65 to 66 years
                                                'B01001_045E', # female 67 to 69 years
                                                'B01001_046E'), # female 70 to 74 years 
                                          geo={'for': 'county:*', 
                                               'in': 'state:{}'.format(states.CA.fips)}, year=census_year))

f_cali_byage.head()
# Out:
#   B01001_031E B01001_032E B01001_033E B01001_034E B01001_035E B01001_036E  \
# 0  20040       10794       11093       32492       59685       61900
# 1  6           22          7           22          27          39
# 2  316         159         83          453         641         694
# 3  4060        2331        2790        7403        6575        6078
# 4  425         151         189         582         838         905
#
#   B01001_037E B01001_038E B01001_039E B01001_040E B01001_041E B01001_042E  \
# 0  58659       58518       56716       57024       50947       18700
# 1  11          28          55          45          52          14
# 2  757         861         1088        1391        1557        817
# 3  5331        6020        6533        7363        7593        3287
# 4  860         1368        1528        2010        2141        717
#
#   B01001_043E B01001_044E B01001_045E B01001_046E  \
# 0  26891       14847       17278       23404
# 1  11          19          10          43
# 2  1003        469         836         1215
# 3  4278        2343        3433        4337
# 4  1490        852         1167        1296
#
#                            NAME county state
# 0  Alameda County, California    001    06
# 1  Alpine County, California     003    06
# 2  Amador County, California     005    06
# 3  Butte County, California      007    06
# 4  Calaveras County, California  009    06

# %%
m_cali_byage.dtypes
# Out:
# B01001_007E    object
# B01001_008E    object
# B01001_009E    object
# B01001_010E    object
# B01001_011E    object
# B01001_012E    object
# B01001_013E    object
# B01001_014E    object
# B01001_015E    object
# B01001_016E    object
# B01001_017E    object
# B01001_018E    object
# B01001_019E    object
# B01001_020E    object
# B01001_021E    object
# B01001_022E    object
# NAME           object
# county         object
# state          object
# dtype: object

# %%
# sum the values for males

m_cali_age = m_cali_byage.copy()

# since the values are stored as objects, we are going to convert them to numberic
m_cali_age = m_cali_age.convert_objects(convert_numeric=True)

# perform the sum
m_cali_age['Total Male Population'] =  m_cali_age['B01001_007E'] +  m_cali_age['B01001_008E'] + m_cali_age['B01001_009E'] + m_cali_age['B01001_010E'] + m_cali_age['B01001_011E'] + m_cali_age['B01001_012E'] + m_cali_age['B01001_013E'] + m_cali_age['B01001_014E'] + m_cali_age['B01001_015E'] + m_cali_age['B01001_016E'] + m_cali_age['B01001_017E'] + m_cali_age['B01001_018E'] + m_cali_age['B01001_019E'] + m_cali_age['B01001_020E'] + m_cali_age['B01001_021E'] + m_cali_age['B01001_022E']
                                                
m_cali_age.head()
# Out:
# /home/pony/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:6: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#    B01001_007E  B01001_008E  B01001_009E  B01001_010E  B01001_011E  \
# 0  20721        10529        11250        33339        59098
# 1  27           15           9            17           31
# 2  453          167          163          653          902
# 3  4116         2865         2126         8534         7269
# 4  494          252          176          631          976
#
#    B01001_012E  B01001_013E  B01001_014E  B01001_015E  B01001_016E  \
# 0  59768        56709        58547        55736        54962
# 1  23           26           85           11           50
# 2  1057         988          1637         1711         1780
# 3  6580         5887         5826         6162         7022
# 4  829          1074         974          1564         1826
#
#    B01001_017E  B01001_018E  B01001_019E  B01001_020E  B01001_021E  \
# 0  48199        17788        22942        13507        15558
# 1  61           16           32           12           31
# 2  1730         695          961          737          814
# 3  7154         2973         4182         2755         2597
# 4  1982         821          1257         757          1115
#
#    B01001_022E                          NAME  county  state  \
# 0  18608        Alameda County, California    1       6
# 1  12           Alpine County, California     3       6
# 2  916          Amador County, California     5       6
# 3  3600         Butte County, California      7       6
# 4  1352         Calaveras County, California  9       6
#
#    Total Male Population
# 0  557261
# 1  458
# 2  15364
# 3  79648
# 4  16080

# %%
# sum the values for females

f_cali_age = f_cali_byage.copy()

# since the values are stored as objects, we are going to convert them to numberic
f_cali_age = f_cali_age.convert_objects(convert_numeric=True)

# perform the sum
f_cali_age['Total Female Population'] =  f_cali_age['B01001_031E'] +  f_cali_age['B01001_032E'] + f_cali_age['B01001_033E'] + f_cali_age['B01001_034E'] + f_cali_age['B01001_035E'] + f_cali_age['B01001_036E'] + f_cali_age['B01001_037E'] + f_cali_age['B01001_038E'] + f_cali_age['B01001_039E'] + f_cali_age['B01001_040E'] + f_cali_age['B01001_041E'] + f_cali_age['B01001_042E'] + f_cali_age['B01001_043E'] + f_cali_age['B01001_044E'] + f_cali_age['B01001_045E'] + f_cali_age['B01001_046E']
                                                
f_cali_age
# Out:
# /home/pony/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:6: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# 49  15628        5763         7448         4776         5897
# 50  2568         1083         1641         807          1319
# 51  2314         874          1202         655          1074
# 52  747          199          391          150          299
# 53  11337        4507         5793         3814         4470
# 54  2613         902          1251         867          1003
# 55  28372        9771         13350        8059         10374
# 56  5578         1942         3459         1532         2447
# 57  1970         841          1178         729          690
#
#     B01001_046E                             NAME  county  state  \
# 0   23404        Alameda County, California       1       6
# 1   43           Alpine County, California        3       6
# 2   1215         Amador County, California        5       6
# 3   4337         Butte County, California         7       6
# 4   1296         Calaveras County, California     9       6
# 5   295          Colusa County, California        11      6
# 6   18704        Contra Costa County, California  13      6
# 7   507          Del Norte County, California     15      6
# 8   3614         El Dorado County, California     17      6
# 9   12707        Fresno County, California        19      6
# 10  499          Glenn County, California         21      6
# 11  2195         Humboldt County, California      23      6
# 12  2545         Imperial County, California      25      6
# 13  269          Inyo County, California          27      6
# 14  10709        Kern County, California          29      6
# ..    ...                            ...          ..     ..
# 43  3788         Santa Cruz County, California    87      6
# 44  4210         Shasta County, California        89      6
# 45  51           Sierra County, California        91      6
# 46  1221         Siskiyou County, California      93      6
# 47  6480         Solano County, California        95      6
# 48  9048         Sonoma County, California        97      6
# 49  7244         Stanislaus County, California    99      6
# 50  1659         Sutter County, California        101     6
# 51  1446         Tehama County, California        103     6
# 52  347          Trinity County, California       105     6
# 53  5025         Tulare County, California        107     6
# 54  1551         Tuolumne County, California      109     6
# 55  12515        Ventura County, California       111     6
# 56  2449         Yolo County, California          113     6
# 57  996          Yuba County, California          115     6
#
#     Total Female Population
# 0   578988
# 1   411
# 2   12340
# 3   79755
# 4   16519
# 5   6716
# 6   388950
# 7   8862
# 8   64954
# 9   312465
# 10  9168
# 11  49508
# 12  56398
# 13  6278
# 14  272240
# ..     ...
# 43  99205
# 44  63844
# 45  1147
# 46  15642
# 47  149772
# 48  179520
# 49  177499
# 50  31969
# 51  21692
# 52  4768
# 53  143226
# 54  18473
# 55  291448
# 56  76771
# 57  24283
#
# [58 rows x 20 columns]

# %%
# this code can be used to replace the above aggregation
f_cali_ageT1 = f_cali_byage.copy()
f_cali_ageT1.drop(['NAME','county','state'], inplace=True, axis=1)
f_cali_ageT1 = f_cali_ageT1.astype(int)
f_cali_ageT1['Total Female Population'] = f_cali_ageT1.sum(axis=1)
f_cali_ageT1 = f_cali_ageT1[['Total Female Population']]
f_cali_ageT = f_cali_age.copy()
f_cali_ageT1 = pd.concat([f_cali_ageT, f_cali_ageT1], axis=1)
f_cali_ageT
# Out:
#     B01001_031E  B01001_032E  B01001_033E  B01001_034E  B01001_035E  \
# 0   20040        10794        11093        32492        59685
# 1   6            22           7            22           27
# 2   316          159          83           453          641
# 3   4060         2331         2790         7403         6575
# 4   425          151          189          582          838
# 5   238          168          150          341          686
# 6   12898        5838         6551         19395        32757
# 7   328          115          128          552          603
# 8   1950         1109         1153         2220         4161
# 9   14346        8822         8180         21416        35009
# 10  376          190          126          555          823
# 11  2505         1670         1203         3278         4610
# 0   23404        Alameda County, California       1       6
# 1   43           Alpine County, California        3       6
# 2   1215         Amador County, California        5       6
# 3   4337         Butte County, California         7       6
# 4   1296         Calaveras County, California     9       6
# 5   295          Colusa County, California        11      6
# 6   18704        Contra Costa County, California  13      6
# 7   507          Del Norte County, California     15      6
# 8   3614         El Dorado County, California     17      6
# 9   12707        Fresno County, California        19      6
# 10  499          Glenn County, California         21      6
# 11  2195         Humboldt County, California      23      6
# 12  2545         Imperial County, California      25      6
# 13  269          Inyo County, California          27      6
# 14  10709        Kern County, California          29      6
# ..    ...                            ...          ..     ..
# 43  3788         Santa Cruz County, California    87      6
# 44  4210         Shasta County, California        89      6
# 45  51           Sierra County, California        91      6
# 46  1221         Siskiyou County, California      93      6
# 47  6480         Solano County, California        95      6
# 48  9048         Sonoma County, California        97      6
# 49  7244         Stanislaus County, California    99      6
# 50  1659         Sutter County, California        101     6
# 51  1446         Tehama County, California        103     6
# 52  347          Trinity County, California       105     6
# 53  5025         Tulare County, California        107     6
# 54  1551         Tuolumne County, California      109     6
# 55  12515        Ventura County, California       111     6
# 56  2449         Yolo County, California          113     6
# 57  996          Yuba County, California          115     6
#
#     Total Female Population
# 0   578988
# 1   411
# 2   12340
# 3   79755
# 4   16519
# 5   6716
# 6   388950
# 7   8862
# 8   64954
# 9   312465
# 10  9168
# 11  49508
# 12  56398
# 13  6278
# 14  272240
# ..     ...
# 43  99205
# 44  63844
# 45  1147
# 46  15642
# 47  149772
# 48  179520
# 49  177499
# 50  31969
# 51  21692
# 52  4768
# 53  143226
# 54  18473
# 55  291448
# 56  76771
# 57  24283
#
# [58 rows x 20 columns]

# %%
# reindex the headers so they align with the labels from our variables table

m_cali_age.rename(columns=df_variables_table.set_index('variables')['label'], inplace=True)

m_cali_age.head()
# Out:
#    Male:!!18 and 19 years  Male:!!20 years  Male:!!21 years  \
# 0  20721                   10529            11250
# 1  27                      15               9
# 2  453                     167              163
# 3  4116                    2865             2126
# 4  494                     252              176
#
#    Male:!!22 to 24 years  Male:!!25 to 29 years  Male:!!30 to 34 years  \
# 0  33339                  59098                  59768
# 1  17                     31                     23
# 2  653                    902                    1057
# 3  8534                   7269                   6580
# 4  631                    976                    829
#
#    Male:!!35 to 39 years  Male:!!40 to 44 years  Male:!!45 to 49 years  \
# 0  56709                  58547                  55736
# 1  26                     85                     11
# 2  988                    1637                   1711
# 3  5887                   5826                   6162
# 4  1074                   974                    1564
#
#    Male:!!50 to 54 years  Male:!!55 to 59 years  Male:!!60 and 61 years  \
# 0  54962                  48199                  17788
# 1  50                     61                     16
# 2  1780                   1730                   695
# 3  7022                   7154                   2973
# 4  1826                   1982                   821
#
#    Male:!!62 to 64 years  Male:!!65 and 66 years  Male:!!67 to 69 years  \
# 0  22942                  13507                   15558
# 1  32                     12                      31
# 2  961                    737                     814
# 3  4182                   2755                    2597
# 4  1257                   757                     1115
#
#    Male:!!70 to 74 years          Geographic Area Name  county  state  \
# 0  18608                  Alameda County, California    1       6
# 1  12                     Alpine County, California     3       6
# 2  916                    Amador County, California     5       6
# 3  3600                   Butte County, California      7       6
# 4  1352                   Calaveras County, California  9       6
#
#    Total Male Population
# 0  557261
# 1  458
# 2  15364
# 3  79648
# 4  16080

# %%
# reindex the headers so they align with the labels from our variables table

f_cali_age.rename(columns=df_variables_table.set_index('variables')['label'], inplace=True)

f_cali_age.head()
# Out:
#    Female:!!18 and 19 years  Female:!!20 years  Female:!!21 years  \
# 0  20040                     10794              11093
# 1  6                         22                 7
# 2  316                       159                83
# 3  4060                      2331               2790
# 4  425                       151                189
#
#    Female:!!22 to 24 years  Female:!!25 to 29 years  Female:!!30 to 34 years  \
# 0  32492                    59685                    61900
# 1  22                       27                       39
# 2  453                      641                      694
# 3  7403                     6575                     6078
# 4  582                      838                      905
#
#    Female:!!35 to 39 years  Female:!!40 to 44 years  Female:!!45 to 49 years  \
# 0  58659                    58518                    56716
# 1  11                       28                       55
# 2  757                      861                      1088
# 3  5331                     6020                     6533
# 4  860                      1368                     1528
#
#    Female:!!50 to 54 years  Female:!!55 to 59 years  Female:!!60 and 61 years  \
# 0  57024                    50947                    18700
# 1  45                       52                       14
# 2  1391                     1557                     817
# 3  7363                     7593                     3287
# 4  2010                     2141                     717
#
#    Female:!!62 to 64 years  Female:!!65 and 66 years  Female:!!67 to 69 years  \
# 0  26891                    14847                     17278
# 1  11                       19                        10
# 2  1003                     469                       836
# 3  4278                     2343                      3433
# 4  1490                     852                       1167
#
#    Female:!!70 to 74 years          Geographic Area Name  county  state  \
# 0  23404                    Alameda County, California    1       6
# 1  43                       Alpine County, California     3       6
# 2  1215                     Amador County, California     5       6
# 3  4337                     Butte County, California      7       6
# 4  1296                     Calaveras County, California  9       6
#
#    Total Female Population
# 0  578988
# 1  411
# 2  12340
# 3  79755
# 4  16519

# %%
# merge the tables together

cali_age = pd.merge(m_cali_age, f_cali_age, on="Geographic Area Name")

cali_age
# Out:
#     Male:!!18 and 19 years  Male:!!20 years  Male:!!21 years  \
# 0   20721                   10529            11250
# 1   27                      15               9
# 2   453                     167              163
# 3   4116                    2865             2126
# 4   494                     252              176
# 5   378                     252              124
# 6   13981                   6970             6500
# 7   442                     206              284
# 8   2337                    1489             975
# 9   15425                   8074             8452
# 10  382                     179              297
# 11  2375                    1718             1356
# 12  2939                    1408             1863
# 13  236                     61               41
# 14  14203                   8327             8657
# ..    ...                    ...              ...
# 43  6229                    3022             2806
# 44  2315                    1207             1258
# 45  51                      15               0
# 46  553                     308              237
# 47  5944                    3307             2760
# 48  6558                    3474             3634
# 49  8223                    4708             3879
# 50  1404                    675              763
# 51  816                     421              310
# 52  173                     22               8
# 53  7480                    4025             3540
# 54  653                     426              207
# 55  12510                   6954             5862
# 56  4824                    3319             2907
# 57  1045                    571              640
#
#     Male:!!22 to 24 years  Male:!!25 to 29 years  Male:!!30 to 34 years  \
# 0   33339                  59098                  59768
# 1   17                     31                     23
# 2   653                    902                    1057
# 13  636                      448
# 14  21830                    8508
# ..    ...                     ...
# 43  10606                    3907
# 44  6966                     2691
# 45  245                      31
# 46  1911                     935
# 47  14698                    5917
# 48  19840                    7755
# 49  15628                    5763
# 50  2568                     1083
# 51  2314                     874
# 52  747                      199
# 53  11337                    4507
# 54  2613                     902
# 55  28372                    9771
# 56  5578                     1942
# 57  1970                     841
#
#     Female:!!62 to 64 years  Female:!!65 and 66 years  \
# 0   26891                    14847
# 1   11                       19
# 2   1003                     469
# 3   4278                     2343
# 4   1490                     852
# 5   324                      193
# 6   19834                    11716
# 7   609                      303
# 8   4025                     2621
# 9   12688                    7457
# 10  549                      307
# 11  2565                     1541
# 12  2421                     1487
# 13  447                      322
# 14  11251                    6245
# ..    ...                     ...
# 43  4456                     2928
# 44  3935                     2302
# 45  103                      99
# 46  1204                     683
# 47  7547                     4450
# 48  9982                     5777
# 49  7448                     4776
# 50  1641                     807
# 51  1202                     655
# 52  391                      150
# 53  5793                     3814
# 54  1251                     867
# 55  13350                    8059
# 56  3459                     1532
# 57  1178                     729
#
#     Female:!!67 to 69 years Female:!!70 to 74 years  county_y  state_y  \
# 0   17278                    23404                   1         6
# 1   10                       43                      3         6
# 2   836                      1215                    5         6
# 3   3433                     4337                    7         6
# 4   1167                     1296                    9         6
# 5   206                      295                     11        6
# 6   13493                    18704                   13        6
# 7   403                      507                     15        6
# 8   2724                     3614                    17        6
# 9   9198                     12707                   19        6
# 10  258                      499                     21        6
# 11  1879                     2195                    23        6
# 12  1755                     2545                    25        6
# 13  355                      269                     27        6
# 14  7873                     10709                   29        6
# ..   ...                       ...                   ..       ..
# 43  3118                     3788                    87        6
# 44  3065                     4210                    89        6
# 45  69                       51                      91        6
# 46  798                      1221                    93        6
# 47  5225                     6480                    95        6
# 48  7810                     9048                    97        6
# 49  5897                     7244                    99        6
# 50  1319                     1659                    101       6
# 51  1074                     1446                    103       6
# 52  299                      347                     105       6
# 53  4470                     5025                    107       6
# 54  1003                     1551                    109       6
# 55  10374                    12515                   111       6
# 56  2447                     2449                    113       6
# 57  690                      996                     115       6
#
#     Total Female Population
# 0   578988
# 1   411
# 2   12340
# 3   79755
# 4   16519
# 5   6716
# 6   388950
# 7   8862
# 8   64954
# 9   312465
# 10  9168
# 11  49508
# 12  56398
# 13  6278
# 14  272240
# ..     ...
# 43  99205
# 44  63844
# 45  1147
# 46  15642
# 47  149772
# 48  179520
# 49  177499
# 50  31969
# 51  21692
# 52  4768
# 53  143226
# 54  18473
# 55  291448
# 56  76771
# 57  24283
#
# [58 rows x 39 columns]

# %%
cali_age_summary = cali_age.copy()
cali_age_summary = cali_age[['Geographic Area Name','county_y','Total Female Population','Total Male Population']]
cali_age_summary.columns= ['Geographic Area Name','County #','Total Female Population','Total Male Population']

cali_age_summary['Total Population'] = cali_age_summary['Total Female Population'] + cali_age_summary['Total Male Population']
cali_age_summary['Female %'] = round((cali_age_summary['Total Female Population'] / cali_age_summary['Total Population'] *100),1).astype(str) + '%'
cali_age_summary['Male %'] = round((cali_age_summary['Total Male Population'] / cali_age_summary['Total Population'] *100),1).astype(str) + '%'

cali_age_summary = cali_age_summary.sort(['Geographic Area Name'], ascending=False)

cali_age_summary
# Out:
# /home/pony/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/pony/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/pony/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/pony/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:9: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                Geographic Area Name  County #  Total Female Population  \
# 57  Yuba County, California          115       24283
# 56  Yolo County, California          113       76771
# 55  Ventura County, California       111       291448
# 54  Tuolumne County, California      109       18473
# 53  Tulare County, California        107       143226
# 52  Trinity County, California       105       4768
# 51  Tehama County, California        103       21692
# 50  Sutter County, California        101       31969
# 49  Stanislaus County, California    99        177499
# 48  Sonoma County, California        97        179520
# 47  Solano County, California        95        149772
# 46  Siskiyou County, California      93        15642
# 45  Sierra County, California        91        1147
# 44  Shasta County, California        89        63844
# 43  Santa Cruz County, California    87        99205
# ..                            ...    ..          ...
# 14  Kern County, California          29        272240
# 13  Inyo County, California          27        6278
# 12  Imperial County, California      25        56398
# 11  Humboldt County, California      23        49508
# 10  Glenn County, California         21        9168
# 9   Fresno County, California        19        312465
# 8   El Dorado County, California     17        64954
# 7   Del Norte County, California     15        8862
# 6   Contra Costa County, California  13        388950
# 5   Colusa County, California        11        6716
# 4   Calaveras County, California     9         16519
# 3   Butte County, California         7         79755
# 2   Amador County, California        5         12340
# 1   Alpine County, California        3         411
# 0   Alameda County, California       1         578988
#
#     Total Male Population  Total Population Female % Male %
# 57  24695                  48978             49.6%    50.4%
# 56  72455                  149226            51.4%    48.6%
# 55  289101                 580549            50.2%    49.8%
# 54  21558                  40031             46.1%    53.9%
# 53  144152                 287378            49.8%    50.2%
# 52  5167                   9935              48.0%    52.0%
# 51  21489                  43181             50.2%    49.8%
# 50  31618                  63587             50.3%    49.7%
# 49  173345                 350844            50.6%    49.4%
# 48  175062                 354582            50.6%    49.4%
# 47  150195                 299967            49.9%    50.1%
# 46  15742                  31384             49.8%    50.2%
# 45  1116                   2263              50.7%    49.3%
# 44  61585                  125429            50.9%    49.1%
# 43  99408                  198613            49.9%    50.1%
# ..    ...                     ...              ...      ...
# 14  296921                 569161            47.8%    52.2%
# 13  6513                   12791             49.1%    50.9%
# 12  60462                  116860            48.3%    51.7%
# 11  50736                  100244            49.4%    50.6%
# 10  9467                   18635             49.2%    50.8%
# 9   313367                 625832            49.9%    50.1%
# 8   65236                  130190            49.9%    50.1%
# 7   11583                  20445             43.3%    56.7%
# 6   369162                 758112            51.3%    48.7%
# 5   7312                   14028             47.9%    52.1%
# 4   16080                  32599             50.7%    49.3%
# 3   79648                  159403            50.0%    50.0%
# 2   15364                  27704             44.5%    55.5%
# 1   458                    869               47.3%    52.7%
# 0   557261                 1136249           51.0%    49.0%
#
# [58 rows x 7 columns]

# %%
grouped = cali_age_summary.copy()
grouped = cali_age_summary.groupby(['Geographic Area Name'])

cali_age_group = grouped['Total Female Population','Total Male Population'].aggregate(np.sum)

cali_age_group
# Out:
#                                  Total Female Population  \
# Geographic Area Name
# Alameda County, California       578988
# Alpine County, California        411
# Amador County, California        12340
# Butte County, California         79755
# Calaveras County, California     16519
# Colusa County, California        6716
# Contra Costa County, California  388950
# Del Norte County, California     8862
# El Dorado County, California     64954
# Fresno County, California        312465
# Glenn County, California         9168
# Humboldt County, California      49508
# Imperial County, California      56398
# Inyo County, California          6278
# Kern County, California          272240
# ...                               ...
# Santa Cruz County, California    99205
# Shasta County, California        63844
# Sierra County, California        1147
# Siskiyou County, California      15642
# Solano County, California        149772
# Sonoma County, California        179520
# Stanislaus County, California    177499
# Sutter County, California        31969
# Tehama County, California        21692
# Trinity County, California       4768
# Tulare County, California        143226
# Tuolumne County, California      18473
# Ventura County, California       291448
# Yolo County, California          76771
# Yuba County, California          24283
#
#                                  Total Male Population
# Geographic Area Name
# Alameda County, California       557261
# Alpine County, California        458
# Amador County, California        15364
# Butte County, California         79648
# Calaveras County, California     16080
# Colusa County, California        7312
# Contra Costa County, California  369162
# Del Norte County, California     11583
# El Dorado County, California     65236
# Fresno County, California        313367
# Glenn County, California         9467
# Humboldt County, California      50736
# Imperial County, California      60462
# Inyo County, California          6513
# Kern County, California          296921
# ...                               ...
# Santa Cruz County, California    99408
# Shasta County, California        61585
# Sierra County, California        1116
# Siskiyou County, California      15742
# Solano County, California        150195
# Sonoma County, California        175062
# Stanislaus County, California    173345
# Sutter County, California        31618
# Tehama County, California        21489
# Trinity County, California       5167
# Tulare County, California        144152
# Tuolumne County, California      21558
# Ventura County, California       289101
# Yolo County, California          72455
# Yuba County, California          24695
#
# [58 rows x 2 columns]

# %%
cali_age_group.plot.barh(title='Total Gender Distribution by County')
plt.gca().invert_yaxis()

# %%
plt.show()

# %%
bayarea_age_summary = cali_age_summary.copy()

bayarea_age_summary

bayarea_age_summary =bayarea_age_summary[bayarea_age_summary['Geographic Area Name'].str.contains("Alameda|Contra Costa|Marin|Napa|San Francisco|San Mateo|Santa Clara|Solano|Sonoma")]

grouped_bayarea = bayarea_age_summary.groupby(['Geographic Area Name'])

bayarea_age_summary = grouped_bayarea['Total Female Population','Total Male Population'].aggregate(np.sum)

bayarea_age_summary
# Out:
#                                   Total Female Population  \
# Geographic Area Name
# Alameda County, California        578988
# Contra Costa County, California   388950
# Marin County, California          93108
# Napa County, California           48722
# San Francisco County, California  319409
# San Mateo County, California      268136
# Santa Clara County, California    647925
# Solano County, California         149772
# Sonoma County, California         179520
#
#                                   Total Male Population
# Geographic Area Name
# Alameda County, California        557261
# Contra Costa County, California   369162
# Marin County, California          90887
# Napa County, California           49134
# San Francisco County, California  341837
# San Mateo County, California      262224
# Santa Clara County, California    662529
# Solano County, California         150195
# Sonoma County, California         175062

# %%
bayarea_age_summary.plot.barh(stacked=True, title='Total Gender Distribution by County')
plt.gca().invert_yaxis()
plt.show()

# %%
cali_age_summary_percent = cali_age.copy()
cali_age_summary_percent = cali_age[['Geographic Area Name','county_y','Total Female Population','Total Male Population']]
cali_age_summary_percent.columns= ['Geographic Area Name','County #','Total Female Population','Total Male Population']

cali_age_summary_percent['Total Population'] = cali_age_summary_percent['Total Female Population'] + cali_age_summary_percent['Total Male Population']
cali_age_summary_percent['Female %'] = round((cali_age_summary_percent['Total Female Population'] / cali_age_summary_percent['Total Population'] *100),1)
cali_age_summary_percent['Male %'] = round((cali_age_summary_percent['Total Male Population'] / cali_age_summary_percent['Total Population'] *100),1)

cali_age_summary_percent = cali_age_summary_percent.sort(['Geographic Area Name'], ascending=False)

cali_age_summary_percent
# Out:
# /home/pony/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/pony/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/pony/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/pony/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:9: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                Geographic Area Name  County #  Total Female Population  \
# 57  Yuba County, California          115       24283
# 56  Yolo County, California          113       76771
# 55  Ventura County, California       111       291448
# 54  Tuolumne County, California      109       18473
# 53  Tulare County, California        107       143226
# 52  Trinity County, California       105       4768
# 51  Tehama County, California        103       21692
# 50  Sutter County, California        101       31969
# 49  Stanislaus County, California    99        177499
# 48  Sonoma County, California        97        179520
# 47  Solano County, California        95        149772
# 46  Siskiyou County, California      93        15642
# 45  Sierra County, California        91        1147
# 44  Shasta County, California        89        63844
# 43  Santa Cruz County, California    87        99205
# ..                            ...    ..          ...
# 14  Kern County, California          29        272240
# 13  Inyo County, California          27        6278
# 12  Imperial County, California      25        56398
# 11  Humboldt County, California      23        49508
# 10  Glenn County, California         21        9168
# 9   Fresno County, California        19        312465
# 8   El Dorado County, California     17        64954
# 7   Del Norte County, California     15        8862
# 6   Contra Costa County, California  13        388950
# 5   Colusa County, California        11        6716
# 4   Calaveras County, California     9         16519
# 3   Butte County, California         7         79755
# 2   Amador County, California        5         12340
# 1   Alpine County, California        3         411
# 0   Alameda County, California       1         578988
#
#     Total Male Population  Total Population  Female %  Male %
# 57  24695                  48978             49.6      50.4
# 56  72455                  149226            51.4      48.6
# 55  289101                 580549            50.2      49.8
# 54  21558                  40031             46.1      53.9
# 53  144152                 287378            49.8      50.2
# 52  5167                   9935              48.0      52.0
# 51  21489                  43181             50.2      49.8
# 50  31618                  63587             50.3      49.7
# 49  173345                 350844            50.6      49.4
# 48  175062                 354582            50.6      49.4
# 47  150195                 299967            49.9      50.1
# 46  15742                  31384             49.8      50.2
# 45  1116                   2263              50.7      49.3
# 44  61585                  125429            50.9      49.1
# 43  99408                  198613            49.9      50.1
# ..    ...                     ...             ...       ...
# 14  296921                 569161            47.8      52.2
# 13  6513                   12791             49.1      50.9
# 12  60462                  116860            48.3      51.7
# 11  50736                  100244            49.4      50.6
# 10  9467                   18635             49.2      50.8
# 9   313367                 625832            49.9      50.1
# 8   65236                  130190            49.9      50.1
# 7   11583                  20445             43.3      56.7
# 6   369162                 758112            51.3      48.7
# 5   7312                   14028             47.9      52.1
# 4   16080                  32599             50.7      49.3
# 3   79648                  159403            50.0      50.0
# 2   15364                  27704             44.5      55.5
# 1   458                    869               47.3      52.7
# 0   557261                 1136249           51.0      49.0
#
# [58 rows x 7 columns]

# %%
grouped_percent = cali_age_summary_percent.copy()
grouped_percent = cali_age_summary_percent.groupby(['Geographic Area Name'])

cali_age_group_percent = grouped_percent['Female %','Male %'].aggregate(np.sum)

cali_age_group_percent
# Out:
#                                  Female %  Male %
# Geographic Area Name
# Alameda County, California       51.0      49.0
# Alpine County, California        47.3      52.7
# Amador County, California        44.5      55.5
# Butte County, California         50.0      50.0
# Calaveras County, California     50.7      49.3
# Colusa County, California        47.9      52.1
# Contra Costa County, California  51.3      48.7
# Del Norte County, California     43.3      56.7
# El Dorado County, California     49.9      50.1
# Fresno County, California        49.9      50.1
# Glenn County, California         49.2      50.8
# Humboldt County, California      49.4      50.6
# Imperial County, California      48.3      51.7
# Inyo County, California          49.1      50.9
# Kern County, California          47.8      52.2
# ...                               ...       ...
# Santa Cruz County, California    49.9      50.1
# Shasta County, California        50.9      49.1
# Sierra County, California        50.7      49.3
# Siskiyou County, California      49.8      50.2
# Solano County, California        49.9      50.1
# Sonoma County, California        50.6      49.4
# Stanislaus County, California    50.6      49.4
# Sutter County, California        50.3      49.7
# Tehama County, California        50.2      49.8
# Trinity County, California       48.0      52.0
# Tulare County, California        49.8      50.2
# Tuolumne County, California      46.1      53.9
# Ventura County, California       50.2      49.8
# Yolo County, California          51.4      48.6
# Yuba County, California          49.6      50.4
#
# [58 rows x 2 columns]

# %%
cali_age_group_percent.plot.barh(stacked=True, title='Total Gender Distribution by County')
plt.gca().invert_yaxis()
plt.show()

# %%
bayarea_age_summary_percent = cali_age_summary_percent.copy()

bayarea_age_summary_percent

bayarea_age_summary_percent =bayarea_age_summary_percent[bayarea_age_summary_percent['Geographic Area Name'].str.contains("Alameda|Contra Costa|Marin|Napa|San Francisco|San Mateo|Santa Clara|Solano|Sonoma")]

grouped_bayarea_percent = bayarea_age_summary_percent.groupby(['Geographic Area Name'])

bayarea_age_summary_percent = grouped_bayarea_percent['Female %','Male %'].aggregate(np.sum)

bayarea_age_summary_percent
# Out:
#                                   Female %  Male %
# Geographic Area Name
# Alameda County, California        51.0      49.0
# Contra Costa County, California   51.3      48.7
# Marin County, California          50.6      49.4
# Napa County, California           49.8      50.2
# San Francisco County, California  48.3      51.7
# San Mateo County, California      50.6      49.4
# Santa Clara County, California    49.4      50.6
# Solano County, California         49.9      50.1
# Sonoma County, California         50.6      49.4

# %%
bayarea_age_summary_percent.plot.barh(stacked=True, title='Total Gender Distribution in SF Bay Area')
plt.gca().invert_yaxis()
plt.show()

# %%
m_cali_age.dtypes

# %%
""" df= pd.DataFrame(ck.acs5.get(('NAME', 'B01001_002E','NAME', 'B01001_026E', 'NAME','B08013_003E'),
          {'for': 'state:{}'.format(states.CA.fips)}, year=census_year))
df

# %%
""""# total population for Yuba County broken out by tract

df3= pd.DataFrame(ck.acs5.get(('NAME','B00001_001E'),geo={'for': 'tract:*', 
               'in': 'state:{} county:115'.format(states.CA.fips)}, year=census_year))
df3

# %%
df5= pd.DataFrame(ck.acs5.get(('NAME','B00001_001E'),
          {'for': 'state:{}'.format(states.RI.fips)}, year=census_year))
df5

# %%
df2 = pd.DataFrame(ck.acs5.get('B01001_004E', {'for': 'state:*'}))
df2.head

# %%
df_variables_table
